# %%
import networkx as nx
import matplotlib.pyplot as plt

g = nx.read_edgelist('D:/Bilal/university/Spring 2019/Discrete structures/project.txt')
print(nx.info(g))

nx.draw(g,with_labels=True)
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 301
# Number of edges: 300
# Average degree:   1.9934

# %%
# basic analysis
ug =g
# number of nodes
print("number of nodes:",nx.number_of_nodes(ug))

#number of edges
print("number of edges:",nx.number_of_edges(ug))

#average clustering
nx.average_clustering(ug)

# diameter
print("Diameter:",nx.diameter(ug))
# this diameter shows ...

# average degree
sum = 0
for n in ug.nodes():
    sum = sum + ug.degree(n)
print("Average degree:", sum/ug.number_of_nodes())
# Out:
# number of nodes: 301
# number of edges: 300
# Diameter: 6
# Average degree: 1.9933554817275747

# %%
def plot_degree_distribution (wiki) :
    degs = {}
    for n in wiki.nodes () :
        deg = wiki.degree ( n )
        
        
        if deg not in degs :
            degs [ deg ] = 0
        
        degs [ deg ] += 1
    items = sorted ( degs.items () )
            
    fig = plt.figure ()
    ax = fig.add_subplot (111)
    ax.plot ([ k for (k , v ) in items ] , [ v for (k ,v ) in items ])
    ax.set_xscale('log')
    ax.set_yscale('log')
    plt.title("Degree Distribution")
    fig.savefig ("degree_distribution.png")
    
            
plot_degree_distribution(g)

# %%
d = [] # create a set
for n in g.nodes():
    d.append(g.degree(n))
    
ec = [] # create a set
for e in g.edges():
    if(g.degree(e[0]) > g.degree(e[1])):
        ec.append(g.degree(e[0]))
    else:
        ec.append(g.degree(e[1]))
    
pos = nx.spring_layout(g, iterations=200)

factor = 200 # to change the size of nodes with respect to their degree


# choose color plate from https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
# example: viridis
nx.draw(g, pos,
        edge_color = ec,  edge_cmap=plt.cm.plasma,  # edge color
        node_color = d, cmap=plt.cm.plasma, # node color
        node_size=[x * factor for x in d]) # node sizse
#3print(ec)
# Out:
# C:\Users\Compro\AppData\Roaming\Python\Python37\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# C:\Users\Compro\AppData\Roaming\Python\Python37\site-packages\networkx\drawing\nx_pylab.py:595: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   for c in edge_color]):

# %%
G = nx.read_edgelist('D:/Bilal/university/spring 2019/discrete structures/project.txt')
pos = nx.spring_layout(G)
colors = range(20)
nx.draw(G, pos, node_color='#A0CBE2', edge_color='red',
        width=4, edge_cmap=plt.cm.Blues, with_labels=False)
plt.show()

# %%
g.degree('CL1PC1')
# Out:
# 1

# %%
for e in g.edges():
    print(e)
# Out:
# ('Uplink', 'Datacentre')
# ('Datacentre', 'Downlink')
# ('Datacentre', 'Switch1CL1')
# ('Datacentre', 'SwitchCL4')
# ('Datacentre', 'Switch1CL2')
# ('Datacentre', 'Switch1CL3')
# ('Datacentre', 'SwitchFYPLab')
# ('Datacentre', 'SwitchLibrary')
# ('Datacentre', 'SwitchRightWing')
# ('Datacentre', 'SwitchLeftWing')
# ('Switch1CL1', 'Switch2CL1')
# ('Switch1CL1', 'Switch3CL1')
# ('Switch1CL1', 'CL1PC1')
# ('Switch1CL1', 'CL1PC2')
# ('Switch1CL1', 'CL1PC3')
# ('Switch1CL1', 'CL1PC4')
# ('Switch1CL1', 'CL1PC5')
# ('Switch1CL1', 'CL1PC6')
# ('Switch1CL1', 'CL1PC7')
# ('Switch1CL1', 'CL1PC8')
# ('Switch1CL1', 'CL1PC9')
# ('Switch1CL1', 'CL1PC10')
# ('Switch1CL1', 'CL1PC11')
# ('Switch1CL1', 'CL1PC12')
# ('Switch1CL1', 'CL1PC13')
# ('Switch1CL1', 'CL1PC14')
# ('Switch1CL1', 'CL1PC15')
# ('Switch1CL1', 'CL1PC16')
# ('Switch1CL1', 'CL1PC17')
# ('Switch1CL1', 'CL1PC18')
# ('Switch1CL1', 'CL1PC19')
# ('Switch1CL1', 'CL1PC20')
# ('Switch1CL1', 'CL1PC21')
# ('Switch1CL1', 'CL1PC22')
# ...

# %%
#G = nx.Graph()
#G.add_edges_from(
 #   [('A', 'B'), ('A', 'C'), ('D', 'B'), ('E', 'C'), ('E', 'F'),
  #   ('B', 'H'), ('B', 'G'), ('B', 'F'), ('C', 'G')])

# val_map = {'G = nx.Graph()
# G.add_edges_from(
#     [('A', 'B'), ('A', 'C'), ('D', 'B'), ('E', 'C'), ('E', 'F'),
#      ('B', 'H'), ('B', 'G'), ('B', 'F'), ('C', 'G')])

# val_map = {G = nx.Graph()
# G.add_edges_from(
#     [('A', 'B'), ('A', 'C'), ('D', 'B'), ('E', 'C'), ('E', 'F'),
#      ('B', 'H'), ('B', 'G'), ('B', 'F'), ('C', 'G')])


val_map = {'CL1PC1': 0.5714285714285714,
'CL1PC2': 0.5714285714285714,
'CL1PC3 ': 0.5714285714285714,
'CL1PC4': 0.5714285714285714,
'CL1PC5': 0.5714285714285714,
'CL1PC6': 0.5714285714285714,
'CL1PC7': 0.5714285714285714,
'CL1PC8': 0.5714285714285714,
'CL1PC9': 0.5714285714285714,
'CL1PC10': 0.5714285714285714,
'CL1PC11': 0.5714285714285714,
'CL1PC12': 0.5714285714285714,
'CL1PC13': 0.5714285714285714,
'CL1PC14': 0.5714285714285714,
'CL1PC15': 0.5714285714285714,
'CL1PC16': 0.5714285714285714,
'CL1PC17': 0.5714285714285714,
'CL1PC18': 0.5714285714285714,
'CL1PC19': 0.5714285714285714,
'CL1PC20': 0.5714285714285714,
'CL1PC21': 0.5714285714285714,
'CL1PC22': 0.5714285714285714,
'CL1PC23': 0.5714285714285714,
'CL1PC24': 0.5714285714285714,
'CL1PC25': 0.5714285714285714,
'CL1PC26': 0.5714285714285714,
'CL1PC27': 0.5714285714285714,
'CL1PC28': 0.5714285714285714,
'CL1PC29': 0.5714285714285714,
'CL1PC30': 0.5714285714285714,
'CL1PC31': 0.5714285714285714,
'CL1PC32': 0.5714285714285714,
'CL1PC33': 0.5714285714285714,
'CL1PC34': 0.5714285714285714,
'CL1PC35': 0.5714285714285714,
'CL1PC36': 0.5714285714285714,
'CL1PC37': 0.5714285714285714,
'CL1PC38': 0.5714285714285714,
'CL1PC39': 0.5714285714285714,
'CL1PC40': 0.5714285714285714,
'CL1PC41': 0.5714285714285714,
'CL1PC42': 0.5714285714285714,
'CL1PC43': 0.5714285714285714,
'CL1PC44': 0.5714285714285714,
'CL1PC45': 0.5714285714285714,
'CL1PC46': 0.5714285714285714,
'CL1PC47': 0.5714285714285714,
'CL1PC48': 0.5714285714285714,
'CL1PC49': 0.5714285714285714,
'CL1PC50': 0.5714285714285714,
'CL1PC51': 0.5714285714285714,
'CL1PC52': 0.5714285714285714,
'CL4PC24': 0.5714285714285714,
'CL4PC25': 0.5714285714285714,
'CL4PC26': 0.5714285714285714,
'CL4PC27': 0.5714285714285714,
'CL4PC28': 0.5714285714285714,
'CL4PC29': 0.5714285714285714,
'CL4PC30': 0.5714285714285714,
'CL4PC31': 0.5714285714285714,
'CL4PC32': 0.5714285714285714,
'CL4PC33': 0.5714285714285714,
'CL4PC34': 0.5714285714285714,
'CL4PC35': 0.5714285714285714,
'CL4PC36': 0.5714285714285714,
'CL4PC37': 0.5714285714285714,
'CL4PC38': 0.5714285714285714,
'CL4PC39': 0.5714285714285714,
'CL4PC40': 0.5714285714285714,
'CL4PC41': 0.5714285714285714,
'CL4PC42': 0.5714285714285714,
'CL4PC43': 0.5714285714285714,
'CL4PC44': 0.5714285714285714,
'CL4PC45': 0.5714285714285714,
'PC101': 0.5714285714285714,
'PC102': 0.5714285714285714,
'PC103': 0.5714285714285714,
'EL1PC1': 0.5714285714285714,
'EL1PC2': 0.5714285714285714,
'PC202': 0.5714285714285714,
'PC201': 0.5714285714285714,
'PC203': 0.5714285714285714,
'PCLH': 0.5714285714285714,
'PC301': 0.5714285714285714,
'PC302': 0.5714285714285714,
'PC303': 0.5714285714285714,
'PCEMD1': 0.5714285714285714,
'PCEMD2': 0.5714285714285714,
'PCDS': 0.5714285714285714,
'EEPC1': 0.5714285714285714,
'EEPC2': 0.5714285714285714,
'EE2PC1': 0.5714285714285714,
'EE2PC2': 0.5714285714285714,
'EE2PC3': 0.5714285714285714,
'EE2PC4': 0.5714285714285714,
'EE2PC5': 0.5714285714285714,
'EE2PC6': 0.5714285714285714,
'EE2PC7': 0.5714285714285714,
'EE2PC8': 0.5714285714285714,
'EE2PC9': 0.5714285714285714,
'EE2PC10': 0.5714285714285714,
'EE2PC11': 0.5714285714285714,
'EE2PC12': 0.5714285714285714,
'EE2PC13': 0.5714285714285714,
'EE2PC14': 0.5714285714285714,
'ISGPC1': 0.5714285714285714,
'ISGPC2': 0.5714285714285714,
'ISGPC3': 0.5714285714285714,
'PC104': 0.5714285714285714,
'CSPC1': 0.5714285714285714,
'CSPC2': 0.5714285714285714,
'Switch1CL1':1,
'Switch2CL1':1,
'Switch3CL1':1,
'SwitchCL4':1,
'Switch1CL2':1,
'Switch2CL2':1,
'Switch1CL3':1,
'Switch2CL3':1,
'SwitchFYPLab':1,
'SwitchLibrary':1,
'SwitchRightWing':1,
'SwitchLeftWing':1



           

           

          }
values = [val_map.get(node, 0.25) for node in g.nodes()]
pos = nx.spring_layout(g, scale=2)

nx.draw(g,node_size=50,edge_color='green',width=1, cmap=plt.get_cmap('viridis'), node_color=values, with_labels=False, font_color='white')
plt.show()

# %%
import collections

degree_sequence = sorted([d for n, d in g.degree()],reverse =True) # degree sequence
degreeCount=collections.Counter(degree_sequence)
deg,cnt=zip (*degreeCount.items())
fig,ax= plt.subplots()
plt.bar(deg,cnt,width=1.0,color='b')
plt.title("Degree Histogram")
plt.xlabel("Count")
plt.ylabel("Degree")
ax.set_xticks([d+0.4 for d in deg])
ax.set_xticklabels(deg)
plt.axes([0.4,0.4,0.5,0.5])
Gcc= sorted(nx.connected_component_subgraphs(g),key=len,reverse=True)[0]
pos=nx.spring_layout(g)
plt.axis('off')
plt.show()
